# %%
from requests import post
import pandas as pd

# %%
rating_80 = post('https://api.igdb.com/v4/games/count', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer nf5vxbcbhcfbxzt4ja91ygs67uybpx'},'data': 'where rating > 80;'})
print ("response: %s" % str(rating_80.json()))
# Out:
# response: {'count': 3992}

# %%
rating_50 = post('https://api.igdb.com/v4/games/count', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer nf5vxbcbhcfbxzt4ja91ygs67uybpx'},'data': 'where rating < 50;'})
print ("response: %s" % str(rating_50.json()))
# Out:
# response: {'count': 2482}

# %%
for i in range(500): 
    rating_80_500 = post('https://api.igdb.com/v4/games', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer nf5vxbcbhcfbxzt4ja91ygs67uybpx'},
                                                    'data': f'fields id, category, game_modes, genres, hypes, created_at, follows, name, platforms, player_perspectives, rating, rating_count, release_dates, themes, total_rating, total_rating_count, language_supports, franchises; rating; where id = {i}; where rating > 80; sort rating desc; limit 500;'})

# %%
df = pd.DataFrame(rating_80_500.json())
df.tail(10)
# Out:
#         id  category  created_at game_modes    genres  hypes  \
# 490  89246         0  1519584778        NaN       [9]    NaN
# 491  89242         0  1519584756        NaN  [13, 14]    NaN
# 492  89201         0  1519469156        NaN      [12]    NaN
# 493  89194         0  1519469051        NaN       NaN    NaN
# 494  89192         0  1519469031        NaN       NaN    NaN
# 495  89188         0  1519468923        NaN      [13]    NaN
# 496  89181         0  1519468856     [1, 2]   [9, 15]    NaN
# 497  89176         0  1519468757        NaN       NaN    NaN
# 498  89153         0  1519468415        NaN       NaN    NaN
# 499  89146         0  1519426842        NaN      [12]    NaN
#
#                                          name        platforms  \
# 490                            Bricks n Balls             [39]
# 491                                 Nova Golf              NaN
# 492                             Magic Mermaid             [39]
# ...

# %%
df.shape
# Out:
# (500, 18)

# %%
for i in range(500, 1000): 
    rating_80_1000 = post('https://api.igdb.com/v4/games', **{'headers': {'Client-ID': 'oxz5ejwdymxkuhbvqv4trcmiw4qaj0', 'Authorization': 'Bearer nf5vxbcbhcfbxzt4ja91ygs67uybpx'},
                                                    'data': f'fields id, category, game_modes, genres, hypes, created_at, follows, name, platforms, player_perspectives, rating, rating_count, release_dates, themes, total_rating, total_rating_count, language_supports, franchises; rating; where id = {i}; where rating > 80; sort rating desc; limit 500;'})

# %%
df = pd.DataFrame(rating_80_1000.json())
df.tail(10)
# Out:
#         id  category  created_at game_modes    genres  hypes  \
# 490  89246         0  1519584778        NaN       [9]    NaN
# 491  89242         0  1519584756        NaN  [13, 14]    NaN
# 492  89201         0  1519469156        NaN      [12]    NaN
# 493  89194         0  1519469051        NaN       NaN    NaN
# 494  89192         0  1519469031        NaN       NaN    NaN
# 495  89188         0  1519468923        NaN      [13]    NaN
# 496  89181         0  1519468856     [1, 2]   [9, 15]    NaN
# 497  89176         0  1519468757        NaN       NaN    NaN
# 498  89153         0  1519468415        NaN       NaN    NaN
# 499  89146         0  1519426842        NaN      [12]    NaN
#
#                                          name        platforms  \
# 490                            Bricks n Balls             [39]
# 491                                 Nova Golf              NaN
# 492                             Magic Mermaid             [39]
# ...
